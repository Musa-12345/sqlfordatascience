# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
#
# # Accessing Databases with SQL Magic
#
#
# Estimated time needed: **15** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Perform simplified database access using SQL "magic"

# %% [markdown]
# ##### To communicate with SQL Databases from within a JupyterLab notebook, we can use the SQL "magic" provided by the [ipython-sql](https://github.com/catherinedevlin/ipython-sql) extension. "Magic" is JupyterLa

# %% [markdown]
# b's term for special commands that start with "%". Below, we'll use the _load_\__ext_ magic to load the ipython-sql extension. In the lab environemnt provided in the course the ipython-sql extension is already installed and so is the ibm_db_sa driver.
#
# The following required modules are pre-installed in the Skills Network Labs environment. However if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you may need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# %pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# %pip uninstall sqlalchemy==1.4 -y  
# %pip install sqlalchemy==1.3.24
# %pip install ipython-sql
# %pip install ibm_db_sa
# %pip install sqlalchemy
# Out:
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Erişim engellendi: 'c:\\Users\\Musa\\anaconda3\\Lib\\site-packages\\sqlalchemy\\cyextension\\collections.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# Collecting sqlalchemy
#   Using cached SQLAlchemy-2.0.19-cp39-cp39-win_amd64.whl (2.0 MB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\musa\anaconda3\lib\site-packages (from sqlalchemy) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\musa\anaconda3\lib\site-packages (from sqlalchemy) (2.0.2)
# Installing collected packages: sqlalchemy
# Collecting ibm_db==3.1.0
#   Using cached ibm_db-3.1.0-py3-none-any.whl
# Collecting ibm_db_sa==0.3.3
#   Using cached ibm_db_sa-0.3.3-py3-none-any.whl
# Collecting sqlalchemy>=0.7.3
#   Using cached SQLAlchemy-2.0.19-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting greenlet!=0.4.17
#   Using cached greenlet-2.0.2-cp39-cp39-win_amd64.whl (192 kB)
# Collecting typing-extensions>=4.2.0
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Installing collected packages: typing-extensions, greenlet, sqlalchemy, ibm-db-sa, ibm-db
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.7.1
#     Uninstalling typing-extensions-4.7.1:
#       Successfully uninstalled typing-extensions-4.7.1
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 2.0.2
#     Uninstalling greenlet-2.0.2:
#       Successfully uninstalled greenlet-2.0.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Erişim engellendi: 'c:\\Users\\Musa\\anaconda3\\Lib\\site-packages\\sqlalchemy\\cyextension\\collections.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Skipping sqlalchemy as it is not installed.
# Collecting sqlalchemy==1.3.24
#   Using cached SQLAlchemy-1.3.24-cp39-cp39-win_amd64.whl (1.2 MB)
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-1.3.24
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.24 which is incompatible.
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# Requirement already satisfied: ipython-sql in c:\users\musa\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\musa\anaconda3\lib\site-packages (from ipython-sql) (3.8.0)
# Requirement already satisfied: six in c:\users\musa\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython in c:\users\musa\anaconda3\lib\site-packages (from ipython-sql) (8.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\musa\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlparse in c:\users\musa\anaconda3\lib\site-packages (from ipython-sql) (0.4.4)
# Collecting sqlalchemy>=2.0
#   Using cached SQLAlchemy-2.0.19-cp39-cp39-win_amd64.whl (2.0 MB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\musa\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\musa\anaconda3\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.7.1)
# Requirement already satisfied: matplotlib-inline in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: decorator in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: colorama in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (61.2.0)
# Requirement already satisfied: pickleshare in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: backcall in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\musa\anaconda3\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\musa\anaconda3\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\musa\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-sql) (0.2.5)
# Requirement already satisfied: asttokens in c:\users\musa\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: executing in c:\users\musa\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\musa\anaconda3\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
#   Rolling back uninstall of SQLAlchemy
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy-1.3.24.dist-info\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\~qlalchemy-1.3.24.dist-info
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\__init__.py
# Note: you may need to restart the kernel to use updated packages.   from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\__pycache__\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\~_pycache__
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\connectors\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\~onnectors
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\cprocessors.cp39-win_amd64.pyd
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\cprocessors.cp39-win_amd64.pyd
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\cresultproxy.cp39-win_amd64.pyd
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\cresultproxy.cp39-win_amd64.pyd
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\cutils.cp39-win_amd64.pyd
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\cutils.cp39-win_amd64.pyd
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\databases\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\~atabases
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\firebird\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\dialects\~irebird
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\__init__.cpython-39.pyc
#
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\adodbapi.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\adodbapi.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\information_schema.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\information_schema.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\mxodbc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\mxodbc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\provision.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\provision.cpython-39.pyc
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Erişim engellendi: 'c:\\Users\\Musa\\anaconda3\\Lib\\site-packages\\sqlalchemy\\cyextension\\collections.cp39-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\pymssql.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\pymssql.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\pyodbc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\pyodbc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\__pycache__\zxjdbc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\__pycache__\zxjdbc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\adodbapi.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\adodbapi.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\information_schema.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\information_schema.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\mxodbc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\mxodbc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\provision.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\provision.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pymssql.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\pymssql.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\pyodbc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\pyodbc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mssql\zxjdbc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mssql\zxjdbc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\cymysql.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\cymysql.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\dml.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\dml.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\enumerated.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\enumerated.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\gaerdbms.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\gaerdbms.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\json.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\json.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\mysqlconnector.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\mysqlconnector.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\mysqldb.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\mysqldb.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\oursql.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\oursql.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\provision.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\provision.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\pymysql.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\pymysql.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\pyodbc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\pyodbc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\reflection.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\reflection.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\types.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\types.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\__pycache__\zxjdbc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\__pycache__\zxjdbc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\cymysql.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\cymysql.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\dml.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\dml.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\enumerated.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\enumerated.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\gaerdbms.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\gaerdbms.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\json.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\json.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqlconnector.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\mysqlconnector.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\mysqldb.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\oursql.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\oursql.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\provision.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\provision.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\pymysql.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\pymysql.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\pyodbc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\pyodbc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\reflection.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\reflection.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\types.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\types.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\zxjdbc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\mysql\zxjdbc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\__pycache__\cx_oracle.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\__pycache__\cx_oracle.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\__pycache__\provision.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\__pycache__\provision.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\__pycache__\zxjdbc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\__pycache__\zxjdbc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\cx_oracle.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\cx_oracle.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\provision.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\provision.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\oracle\zxjdbc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\oracle\zxjdbc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\array.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\array.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\dml.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\dml.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\ext.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\ext.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\hstore.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\hstore.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\json.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\json.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\pg8000.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\pg8000.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\provision.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\provision.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\psycopg2.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\psycopg2.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\psycopg2cffi.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\psycopg2cffi.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\pygresql.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\pygresql.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\pypostgresql.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\pypostgresql.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\ranges.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\ranges.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\__pycache__\zxjdbc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\__pycache__\zxjdbc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\array.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\array.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\dml.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\dml.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\ext.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\ext.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\hstore.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\hstore.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\json.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\json.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\pg8000.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\pg8000.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\provision.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\provision.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\psycopg2.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2cffi.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\psycopg2cffi.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\pygresql.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\pygresql.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\pypostgresql.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\pypostgresql.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\ranges.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\ranges.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\zxjdbc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\postgresql\zxjdbc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\__pycache__\json.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\__pycache__\json.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\__pycache__\provision.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\__pycache__\provision.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\__pycache__\pysqlcipher.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\__pycache__\pysqlcipher.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\__pycache__\pysqlite.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\__pycache__\pysqlite.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\json.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\json.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\provision.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\provision.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\pysqlcipher.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\pysqlcipher.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sqlite\pysqlite.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\dialects\sqlite\pysqlite.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\dialects\sybase\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\dialects\~ybase
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\default.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\default.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\interfaces.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\interfaces.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\reflection.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\reflection.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\result.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\result.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\strategies.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\strategies.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\threadlocal.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\threadlocal.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\url.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\url.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\__pycache__\util.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\__pycache__\util.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\default.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\default.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\interfaces.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\interfaces.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\reflection.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\result.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\result.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\strategies.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\strategies.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\threadlocal.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\threadlocal.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\url.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\url.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\engine\util.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\engine\util.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\event\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\~vent
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\events.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\events.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\exc.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\exc.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\__pycache__\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\ext\~_pycache__
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\associationproxy.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\associationproxy.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\automap.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\automap.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\baked.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\baked.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\compiler.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\compiler.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\__pycache__\api.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\__pycache__\api.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\__pycache__\clsregistry.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\__pycache__\clsregistry.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\api.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\api.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\declarative\clsregistry.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\declarative\clsregistry.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\horizontal_shard.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\horizontal_shard.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\hybrid.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\hybrid.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\indexable.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\indexable.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\instrumentation.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\instrumentation.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\mutable.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\mutable.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\orderinglist.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\orderinglist.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\ext\serializer.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\ext\serializer.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\inspection.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\inspection.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\interfaces.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\interfaces.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\log.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\log.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\attributes.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\attributes.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\base.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\base.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\collections.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\collections.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\dependency.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\dependency.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\deprecated_interfaces.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\deprecated_interfaces.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\descriptor_props.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\descriptor_props.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\dynamic.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\dynamic.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\evaluator.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\evaluator.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\events.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\events.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\exc.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\exc.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\identity.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\identity.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\instrumentation.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\instrumentation.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\interfaces.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\interfaces.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\loading.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\loading.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\mapper.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\mapper.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\path_registry.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\path_registry.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\persistence.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\persistence.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\properties.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\properties.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\query.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\query.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\relationships.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\relationships.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\scoping.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\scoping.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\session.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\session.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\state.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\state.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\strategies.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\strategies.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\strategy_options.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\strategy_options.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\sync.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\sync.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\unitofwork.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\unitofwork.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\__pycache__\util.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\__pycache__\util.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\attributes.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\attributes.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\base.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\base.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\collections.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\collections.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\dependency.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\dependency.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\orm\deprecated_interfaces.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\orm\deprecated_interfaces.py
# ...
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\assertions.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\assertions.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\assertsql.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\assertsql.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\config.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\config.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\engines.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\engines.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\entities.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\entities.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\exclusions.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\exclusions.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\fixtures.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\fixtures.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\mock.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\mock.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\pickleable.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\pickleable.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\profiling.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\profiling.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\provision.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\provision.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\replay_fixture.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\replay_fixture.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\requirements.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\requirements.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\schema.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\schema.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\util.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\util.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\__pycache__\warnings.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\__pycache__\warnings.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\assertions.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\assertions.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\assertsql.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\assertsql.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\config.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\config.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\engines.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\engines.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\entities.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\entities.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\exclusions.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\exclusions.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\fixtures.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\fixtures.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\mock.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\mock.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\pickleable.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\pickleable.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\plugin\
#    from C:\Users\Musa\anaconda3\Lib\site-packages\sqlalchemy\testing\~lugin
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\profiling.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\profiling.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\provision.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\provision.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\replay_fixture.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\replay_fixture.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\requirements.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\requirements.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\schema.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\schema.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_cte.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_cte.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_ddl.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_ddl.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_dialect.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_dialect.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_insert.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_insert.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_reflection.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_reflection.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_results.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_results.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_select.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_select.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_sequence.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_sequence.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_types.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_types.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\__pycache__\test_update_delete.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\__pycache__\test_update_delete.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_cte.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_cte.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_ddl.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_ddl.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_dialect.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_dialect.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_insert.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_insert.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_reflection.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_reflection.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_results.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_results.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_select.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_select.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_sequence.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_sequence.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_types.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_types.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\suite\test_update_delete.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\suite\test_update_delete.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\util.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\util.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\testing\warnings.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\testing\warnings.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\types.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\types.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__init__.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__init__.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\__init__.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\__init__.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\_collections.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\_collections.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\_preloaded.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\_preloaded.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\compat.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\compat.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\deprecations.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\deprecations.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\langhelpers.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\langhelpers.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\queue.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\queue.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\__pycache__\topological.cpython-39.pyc
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\__pycache__\topological.cpython-39.pyc
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\_collections.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\_preloaded.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\_preloaded.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\compat.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\compat.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\deprecations.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\langhelpers.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\queue.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\queue.py
#   Moving to c:\users\musa\anaconda3\lib\site-packages\sqlalchemy\util\topological.py
#    from C:\Users\Musa\AppData\Local\Temp\pip-uninstall-tml8ovf4\util\topological.py
# Requirement already satisfied: ibm_db_sa in c:\users\musa\anaconda3\lib\site-packages (0.3.3)
# Requirement already satisfied: sqlalchemy>=0.7.3 in c:\users\musa\anaconda3\lib\site-packages (from ibm_db_sa) (1.3.24)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# Requirement already satisfied: sqlalchemy in c:\users\musa\anaconda3\lib\site-packages (1.3.24)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\users\musa\anaconda3\lib\site-packages)

# %%
# %load_ext sql
import ibm_db
from sqlalchemy import create_engine

# %% [markdown]
# ##### Now we have access to SQL magic. With our first SQL magic command, we'll connect to a Db2 database. However, in order to do that, you'll first need to retrieve or create your credentials to access your Db2 database.

# %% [markdown]
# <a ><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/images/details.png" width="1000," align="center"></a>
#   <h5 align=center>  This image shows the location of your connection string if you're using Db2 on IBM Cloud. If you're using another host the format is: username:password@hostname:port/database-name?security=SSL
#   </h5>

# %% [markdown]
# ##### For convenience, we can use %%sql (two %'s instead of one) at the top of a cell to indicate we want the entire cell to be treated as SQL. Let's use this to create a table and fill it with some test data for experimenting.

# %%
# Enter your Db2 credentials in the connection string below
# Recall you created Service Credentials in Part III of the first lab of the course in Week 1
# i.e. from the uri field in the Service Credentials copy everything after db2:// (but remove the double quote at the end)
# for example, if your credentials are as in the screenshot above, you would write:
# %sql ibm_db_sa://my-username:my-password@hostname:port/BLUDB?security=SSL
# Note the ibm_db_sa:// prefix instead of db2://
# This is because JupyterLab's ipython-sql extension uses sqlalchemy (a python SQL toolkit)
# which in turn uses IBM's sqlalchemy dialect: ibm_db_sa
dsn_hostname = "0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_uid = "cvk04287"        # e.g. "abc12345"
dsn_pwd =  "Kfn1gFIEDgHYU8pg"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "bludb"            # e.g. "BLUDB"
dsn_port =  "31198"             # e.g. "32733" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"              #i.e. "SSL"

# %%
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

#print the connection string to check correct values are specified
print(dsn)
# Out:
# DRIVER={IBM DB2 ODBC DRIVER};DATABASE=bludb;HOSTNAME=0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud;PORT=31198;PROTOCOL=TCPIP;UID=cvk04287;PWD=Kfn1gFIEDgHYU8pg;SECURITY=SSL;

# %%
try:
    conn = ibm_db.connect(dsn, dsn_uid, dsn_pwd)
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  bludb as user:  cvk04287 on host:  0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud

# %%
# %sql ibm_db_sa://cvk04287:Kfn1gFIEDgHYU8pg@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/db2-yy
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 552, in create_engine
#     entrypoint = u._get_entrypoint()
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\engine\url.py", line 754, in _get_entrypoint
#     cls = registry.load(name)
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 355, in load
#     return self.impls[name]()
#   File "c:\Users\Musa\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 194, in load
#     module = import_module(match.group('module'))
#   File "c:\Users\Musa\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "c:\Users\Musa\anaconda3\lib\site-packages\ibm_db_sa\__init__.py", line 22, in <module>
#     from . import ibm_db, pyodbc, base, zxjdbc
#   File "c:\Users\Musa\anaconda3\lib\site-packages\ibm_db_sa\ibm_db.py", line 21, in <module>
#     from sqlalchemy import processors, types as sa_types, util
# ImportError: cannot import name 'processors' from 'sqlalchemy' (c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\__init__.py)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Traceback (most recent call last):
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sql\connection.py", line 70, in set
#     cls.current = existing or Connection(descriptor, connect_args, creator)
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 552, in create_engine
#     entrypoint = u._get_entrypoint()
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\engine\url.py", line 754, in _get_entrypoint
#     cls = registry.load(name)
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 355, in load
#     return self.impls[name]()
#   File "c:\Users\Musa\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 194, in load
#     module = import_module(match.group('module'))
#   File "c:\Users\Musa\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 972, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "c:\Users\Musa\anaconda3\lib\site-packages\ibm_db_sa\__init__.py", line 22, in <module>
#     from . import ibm_db, pyodbc, base, zxjdbc
#   File "c:\Users\Musa\anaconda3\lib\site-packages\ibm_db_sa\ibm_db.py", line 21, in <module>
#     from sqlalchemy import processors, types as sa_types, util
# ImportError: cannot import name 'processors' from 'sqlalchemy' (c:\Users\Musa\anaconda3\lib\site-packages\sqlalchemy\__init__.py)
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# )
# INSERT INTO INTERNATIONAL_STUDENT_TEST_SCORES (country, first_name, last_name, test_score)
# VALUES
# ('United States', 'Marshall', 'Bernadot', 54),
# ('Ghana', 'Celinda', 'Malkin', 51),
# ('Ukraine', 'Guillermo', 'Furze', 53),
# ('Greece', 'Aharon', 'Tunnow', 48),
# ('Russia', 'Bail', 'Goodwin', 46),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 53),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sql\magic.py", line 196, in execute
#     conn = sql.connection.Connection.set(
#   File "c:\Users\Musa\anaconda3\lib\site-packages\sql\connection.py", line 82, in set
#     raise ConnectionError(
# sql.connection.ConnectionError: Environment variable $DATABASE_URL not set, and no connect string given.
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# #### Using Python Variables in your SQL Statements
# ##### You can use python variables in your SQL statements by adding a ":" prefix to your python variable names.
# ##### For example, if I have a python variable `country` with a value of `"Canada"`, I can use this variable in a SQL query to find all the rows of students from Canada.

# %%
country = "Canada"
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES where country = :country

# %% [markdown]
# #### Assigning the Results of Queries to Python Variables

# %% [markdown]
# ##### You can use the normal python assignment syntax to assign the results of your queries to python variables.
# ##### For example, I have a SQL query to retrieve the distribution of test scores (i.e. how many students got each score). I can assign the result of this query to the variable `test_score_distribution` using the `=` operator.

# %%
test_score_distribution = %sql SELECT test_score as "Test Score", count(*) as "Frequency" from INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score;
test_score_distribution

# %% [markdown]
# #### Converting Query Results to DataFrames

# %% [markdown]
# ##### You can easily convert a SQL query result to a pandas dataframe using the `DataFrame()` method. Dataframe objects are much more versatile than SQL query result objects. For example, we can easily graph our test score distribution after converting to a dataframe.

# %%
dataframe = test_score_distribution.DataFrame()

# %matplotlib inline
# uncomment the following line if you get an module error saying seaborn not found
# !pip install seaborn==0.9.0
import seaborn

plot = seaborn.barplot(x='Test Score',y='Frequency', data=dataframe)

# %% [markdown]
# Now you know how to work with Db2 from within JupyterLab notebooks using SQL "magic"!

# %%
# %%sql
#
# -- Feel free to experiment with the data set provided in this notebook for practice:
# SELECT country, first_name, last_name, test_score FROM INTERNATIONAL_STUDENT_TEST_SCORES;

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDB0201ENSkillsNetwork22-2022-01-01" target="_blank">Rav Ahuja</a>
#
#
#
# ## Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2021-11-17  | 2.3  | Lakshmi  | Updated library  |
# | 2021-07-09 | 2.2 | Malika | Updated sql magic connection string and screenshot |
# | 2021-05-06 | 2.1 |Malika Singla | Added libraries |
# | 2020-07-17  | 2.0  | Lavanya  |  Moved lab to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
